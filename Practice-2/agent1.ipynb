# %%
#import libraries
from typing import TypedDict,List
from langchain_core.messages import HumanMessage
from langchain_openai import ChatOpenAI
from langgraph.graph import StateGraph,START,END
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
class AgentState(TypedDict):
    message:List[HumanMessage]

llm=ChatOpenAI(model="gpt-4o")

def process_node(state:AgentState)->AgentState:
    """These is function used to process human inputs"""
    response=llm.invoke(state["message"])
    print(f"AI :{response.content}")
    return state

graph=StateGraph(AgentState)
graph.add_node("Processor",process_node)
graph.add_edge(START,"Processor")
graph.add_edge("Processor",END)

agent=graph.compile()

while user_input!="exit":
    user_input=input("Enter: ")
    agent.invoke({"message":[HumanMessage(content=user_input)]})
# Out:
# AI :Hello! How can I assist you today?
# AI :Hello Jayanth! The sum of 2 and 9 is 11.
# AI :If you're looking to end our session or conversation, feel free to close this window or tab. If you have any other questions or need further assistance, feel free to ask. Have a great day!
